# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= sns.load_dataset('iris')
#iris is a inbuilt dataste, which is avilable in sns

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
#It will plot all the integer dataset
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind=  "area", alpha=0.5, stacked= False)
#Here alpha is a parameter to control the column
#Satcked false will avoide the operlapping the map
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x="sepal_length" , y = "sepal_width")

#It is a comparison scatter map between sepal_length and sepal_width

#Conclusion- There is no relation  as the dataset is completly distributed.
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x="sepal_length" , y = "petal_length")
#Conclusion- If sepal lenght is increasing then petal lenghth is also increasing
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x="sepal_length" , y = "petal_length", c= "sepal_width", s=100)
# "C" represents the colour of the graph. According the value of sepal_lenght, here colour is described
#S represents the size of the
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x ='sepal_length' , y ='petal_length',gridsize=10,cmap="viridis")
# here (cmap="viridis" ) will change the colour of the map
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
 from mpl_toolkits import mplot3d

# %%
x= np.linspace(-1,6,30)
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y= np.linspace(-1,6,30)
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
z= x+y
z
# Out:
# array([-2.        , -1.51724138, -1.03448276, -0.55172414, -0.06896552,
#         0.4137931 ,  0.89655172,  1.37931034,  1.86206897,  2.34482759,
#         2.82758621,  3.31034483,  3.79310345,  4.27586207,  4.75862069,
#         5.24137931,  5.72413793,  6.20689655,  6.68965517,  7.17241379,
#         7.65517241,  8.13793103,  8.62068966,  9.10344828,  9.5862069 ,
#        10.06896552, 10.55172414, 11.03448276, 11.51724138, 12.        ])

# %%
ax= plt.axes(projection="3d")
#plt is a alias for the matplotlib
ax.plot3D(x,y,z)
ax.set_xlabel('x')
#it will alocate the value "x" to the x label and similar in  y and z labl
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax= plt.axes(projection="3d")
ax.plot3D(df["sepal_length"],df["petal_length"],df["petal_width"])
ax.set_xlabel('sepal_length')
ax.set_ylabel('petal_length')
ax.set_zlabel('petal_width')
# Out:
# Text(0.5, 0, 'petal_width')

# %%
df.plot(figsize=(20,10))
#figsize will increase the window size so the graph could be more clear
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind="barh", figsize=(20,10))
#as here the dataset is huge, so we used iloc to select a specific dataset
#"kind = bar"= vertical represtentation,
#"kind = barh"= Horizontal representation
# Out:
# <AxesSubplot:>

# %%
df

# %%
df.plot(kind="hist", figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind="hist",figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(20,10),color ='#03203C', alpha=0.9)
#for color we have taken "g" and for the darkness of the graphn we used 'alpha'
#go to learncode online and use the coloue code for the graph."#03203C" is derived from that website
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="c06ef0e7-3f23-419d-a911-c6a833775f12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x="sepal_length" , y = "sepal_width", size= 'petal_width', kind= 'bubble',color="#F7CD2E")
# Out:
# <div>                            <div id="8976e1b4-91c9-4605-ab3b-389dc6b7a073" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x="sepal_length" , y = "sepal_width", z= 'petal_width',size= "petal_length", kind= 'bubble3d')
#for 3d graph we need x,y ,z value.
# Out:
# <div>                            <div id="22ab62a5-171b-4e5e-8c00-6bb545f1d26f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1=sns.load_dataset('tips')
#tips is a inbuilt dataset present in sns

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x='total_bill',y='tip',kind='scatter')
#you can allocate x and y or else you can write like this "df1.plot('total_bill','tip',kind='scatter')"

#conclusion- here higher the bill is tends to higher tip
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x='total_bill',y='tip',kind='scatter',mode="markers")
# Out:
# <div>                            <div id="92f74ef2-1fe3-4c6b-8702-75a86736dd2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x="total_bill",y="tip",data=df1, hue='smoker',style="time")
            
#hue highlights the graph group wise. here in smoker column it's showing "yes" or "no", only 2 groups. so the garph is flagged in 2 colour
#style will show case time , when the tip is high or low and the person is smoker or non smoker
#we can visualise the similar graph through 3 diffferent library 1st one is matplotlib then cufflinks,where we can interact with data while pointing the crusher and 3rd one is seaborn library

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=df1, hue='sex',style="time")

#conclusion-the highest tips was given by a male and the time was dinner time

# %%
sns.relplot(x= 'total_bill', y='tip',data=df1,col='time')
# In time column there is 2 category data. by "col" it will create separate graph as per the category

# %%
sns.relplot(x='sepal_length',y="sepal_width",data=df, col= "species")
#here in species , there are 3 category. so it will create 3 graphs

# %%
sns.catplot(x='day',y="total_bill",data=df1,col='sex')
#catplot means categorical plot. it represents the data categorywise.

# %%
#histogram= on x axis it show the ranges and on y-axis it shows the frequency.

# %%
sns.pairplot(df1)
#pairplot helps to compare all the interger columns. like here totsl bill is compared with size, total_bill and tip etc

# %%
sns.pairplot(df)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="f12f617e-517b-4a8f-8095-6e7c52a2e35b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(df1.total_bill, y= df1.tip, kind= 'hex')
#This will show scatter and histogram at same time.
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.regplot(x=df1.total_bill,y=df1.tip)
sns.set(rc={'figure.figsize':(20,10)})
#sns.set line will help to set the figsize
#regplot represnts regression plot
#it will draw the regression line

# %%
import plotly.express as px

fig=px.bar(df1,x="sex", y= "total_bill",color='smoker',barmode='group')
fig.show()
# Out:
# <div>                            <div id="13fd67cc-4ff6-4ea9-ad52-18bdd1e73d73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13fd67cc-4ff6-4ea9-ad52-18bdd1e73d73")) {                    Plotly.newPlot(                        "13fd67cc-4ff6-4ea9-ad52-18bdd1e73d73",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...
